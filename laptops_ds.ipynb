# %%
import requests
laptop_info = requests.get('https://laptop251.com/best-laptops-for-data-science/')
laptop_info.content
# Out:
# b'<!doctype html >\r\n<!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->\r\n<!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->\r\n<!--[if gt IE 8]><!--> <html lang="en-US" prefix="og: https://ogp.me/ns#"> <!--<![endif]-->\r\n<head><meta charset="UTF-8" /><script>if(navigator.userAgent.match(/MSIE|Internet Explorer/i)||navigator.userAgent.match(/Trident\\/7\\..*?rv:11/i)){var href=document.location.href;if(!href.match(/[?&]nowprocket/)){if(href.indexOf("?")==-1){if(href.indexOf("#")==-1){document.location.href=href+"?nowprocket=1"}else{document.location.href=href.replace("#","?nowprocket=1#")}}else{if(href.indexOf("#")==-1){document.location.href=href+"&nowprocket=1"}else{document.location.href=href.replace("#","&nowprocket=1#")}}}}</script><script>class RocketLazyLoadScripts{constructor(e){this.triggerEvents=e,this.eventOptions={passive:!0},this.userEventListener=this.triggerListener.bind(this),this.delayedScripts={normal:[],async:[],defer:[]},this.allJQueries=[]}_a
# ...

# %%
from bs4 import BeautifulSoup
ds_laptops = BeautifulSoup(laptop_info.content, 'html.parser')
[type(item) for item in list(ds_laptops)]
# Out:
# [bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Comment]

# %%
nav_site_laptops = list(ds_laptops)[8]
len(nav_site_laptops)
# Out:
# 7

# %%
print(nav_site_laptops.find_all(class_= ['column-1', 'column-2', 'column-3']))
# Out:
# [<th class="column-1"> </th>, <th class="column-2"><b>Minimum System Requirements</b></th>, <th class="column-3"><b>Recommended System Requirements</b></th>, <td class="column-1"><b>CPU</b></td>, <td class="column-2">Intel Core i5 (8th Gen)</td>, <td class="column-3">Intel Core i7 (10th Gen)</td>, <td class="column-1"><b>RAM</b></td>, <td class="column-2">8GB</td>, <td class="column-3">16GB</td>, <td class="column-1"><b>Storage</b></td>, <td class="column-2">256GB SSD</td>, <td class="column-3">512GB SSD or 256GB SSD + 1TB HDD</td>, <td class="column-1"><b>Display</b></td>, <td class="column-2">13.3-inch FHD (1920 x 1080)</td>, <td class="column-3">15.6-inch FHD IPS (1920 x 1080)</td>, <td class="column-1"><b>GPU</b></td>, <td class="column-2">Integrated Intel UHD 620</td>, <td class="column-3">4GB NVIDIA GeForce GTX 1650</td>, <td class="column-1"><b>Battery</b></td>, <td class="column-2">Up to 4 hours</td>, <td class="column-3">Up to 8 hours</td>, <th class="column-1">Image</th>, <
# ...
