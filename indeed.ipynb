# %%
import requests
page = requests.get('https://ng.indeed.com/?r=us')
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html dir="ltr" lang="en">\n    <head>\n\n    <script src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/ea1c9c9/en_NG.min.js" defer></script>\n    <script></script>\n    <script src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/d711fc6ff301ce1ff9d6/scripts/homepage.js" crossorigin="anonymous" defer></script>\n            <meta name="description" content="With Indeed, you can search millions of jobs online to find the next step in your career. With tools for job search, resumes, company reviews and more, were with you every step of the way."/>\n    <meta name="keywords" content="job search, Indeed, jobs, search engine for jobs, job search engine, job listings, search jobs, career, employment, work, find jobs, rss jobs feed xml "/>\n    <meta charset="utf-8"/>\n    <meta content="ie=edge" http-equiv="x-ua-compatible"/>\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0"/>\n    <meta name="google" content="notranslate"/>\n    <met
# ...

# %%
from bs4 import BeautifulSoup
indeed_data = BeautifulSoup(page.content, 'html.parser')
print(indeed_data.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <script defer="" src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/ea1c9c9/en_NG.min.js">
#   </script>
#   <script>
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/d711fc6ff301ce1ff9d6/scripts/homepage.js">
#   </script>
#   <meta content="With Indeed, you can search millions of jobs online to find the next step in your career. With tools for job search, resumes, company reviews and more, were with you every step of the way." name="description"/>
#   <meta content="job search, Indeed, jobs, search engine for jobs, job search engine, job listings, search jobs, career, employment, work, find jobs, rss jobs feed xml " name="keywords"/>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
#   <meta content="notranslate" name="google"/>
# ...

# %%
list(indeed_data.children)
# Out:
# ['html',
#  '\n',
#  <html dir="ltr" lang="en">
#  <head>
#  <script defer="" src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/ea1c9c9/en_NG.min.js"></script>
#  <script></script>
#  <script crossorigin="anonymous" defer="" src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/d711fc6ff301ce1ff9d6/scripts/homepage.js"></script>
#  <meta content="With Indeed, you can search millions of jobs online to find the next step in your career. With tools for job search, resumes, company reviews and more, were with you every step of the way." name="description"/>
#  <meta content="job search, Indeed, jobs, search engine for jobs, job search engine, job listings, search jobs, career, employment, work, find jobs, rss jobs feed xml " name="keywords"/>
#  <meta charset="utf-8"/>
#  <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#  <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
#  <meta content="notranslate" name="google"/>
# ...

# %%
[type(item) for item in list(indeed_data.children)]
# Out:
# [bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
html = list(indeed_data.children)[2]
html
# Out:
# <html dir="ltr" lang="en">
# <head>
# <script defer="" src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/ea1c9c9/en_NG.min.js"></script>
# <script></script>
# <script crossorigin="anonymous" defer="" src="https://d3fw5vlhllyvee.cloudfront.net/hp/s/d711fc6ff301ce1ff9d6/scripts/homepage.js"></script>
# <meta content="With Indeed, you can search millions of jobs online to find the next step in your career. With tools for job search, resumes, company reviews and more, were with you every step of the way." name="description"/>
# <meta content="job search, Indeed, jobs, search engine for jobs, job search engine, job listings, search jobs, career, employment, work, find jobs, rss jobs feed xml " name="keywords"/>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <meta content="notranslate" name="google"/>
# ...

# %%
sample_data = list(html.children)
sample_data[3]
# Out:
# <body>
# <script>
# ...

# %%
indeed_links = sample_data[1].find_all('link')
indeed_links
# Out:
# [<link href="/" rel="canonical"/>,
#  <link href="https://ng.indeed.com/m/" media="screen" rel="alternate"/>,
#  <link href="/images/favicon.ico" rel="shortcut icon"/>,
#  <link href="https://ae.indeed.com/" hreflang="en-ae" rel="alternate"/>,
#  <link href="https://at.indeed.com/" hreflang="de-at" rel="alternate"/>,
#  <link href="https://emplois.be.indeed.com/" hreflang="fr-be" rel="alternate"/>,
#  <link href="https://be.indeed.com/" hreflang="nl-be" rel="alternate"/>,
#  <link href="https://bh.indeed.com/" hreflang="en-bh" rel="alternate"/>,
#  <link href="https://ch.indeed.com/" hreflang="de-ch" rel="alternate"/>,
#  <link href="https://ch-fr.indeed.com/" hreflang="fr-ch" rel="alternate"/>,
#  <link href="https://cz.indeed.com/" hreflang="cs-cz" rel="alternate"/>,
#  <link href="https://de.indeed.com/" hreflang="de-de" rel="alternate"/>,
#  <link href="https://dk.indeed.com/" hreflang="da-dk" rel="alternate"/>,
# ...
